# %% [markdown]
# <a href="https://colab.research.google.com/github/Chen-Mei-Chen/Python_Self_Learning/blob/main/%3CPython%E7%AD%86%E8%A8%98%3EMatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SciencePlots
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting SciencePlots
#   Downloading SciencePlots-2.1.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from SciencePlots) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SciencePlots) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->SciencePlots) (1.17.0)
# Downloading SciencePlots-2.1.1-py3-none-any.whl (16 kB)
# Installing collected packages: SciencePlots
# Successfully installed SciencePlots-2.1.1

# %% [markdown]
# # Making Plots Actually Look Nice
#
# If one has SciencePlots (https://github.com/garrettj403/SciencePlots) installed has additional options for matplotlib

# %%
import scienceplots
plt.style.use(['science', 'notebook', 'grid']) #使用這行，可以把製圖風格變得更科學

# %% [markdown]
# # Quick Plotting

# %% [markdown]
# ## Line Plots

# %% [markdown]
# Simple plotting commands to look at data quickly

# %%
x = np.linspace(0,15,30) #產生0到15間的數，並等分為30個數
y = np.sin(x) + 0.1*np.random.randn(len(x))
#以sin函數為基礎再加上一些雜訊，這個雜訊是由高斯分布(90%為+-3)之間的數隨機挑選再乘0.1，然後產生30個(len(30))

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, 'o-', color='purple', lw=2, ms=10)

# o:點、-:線、--:虛線 ; lw是線寬 ; ms是點點大小

# %% [markdown]
# Figure size

# %%
plt.figure(figsize=(8,3)) #這是圖片長寬比設定
plt.plot(x,y)

# %% [markdown]
# Axis labels

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y)

#x、y軸及其設定
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]')

#圖表標題
plt.title('Voltage in 3rd Electrode')
plt.show()

# %% [markdown]
# Legend

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, label='Component 1') #標籤
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='lower right', fontsize=18) #標籤的相關設定
plt.show()

# %% [markdown]
# Easy to have multiple lines on same plot

# %%
#產生第二組數據:sin函數
x2 = np.linspace(0, 15, 100)
y2 = np.sin(x2)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, 'o', label='Data', zorder=100)
plt.plot(x2,y2, label='Fit')
# 由此可以看出label可以為每組數據指定標籤名稱，而zorder是「圖層優先順序」，數字越大，圖層越上面（越後畫）
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='lower right', fontsize=12)
plt.show()

# %% [markdown]
# $x$ and $y$ limits

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, 'o', label='Data', zorder=100)
plt.plot(x2,y2, label='Fit')
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='upper right', fontsize=12, ncol=2) # ncol是把標籤變兩欄，怕擋到數據
plt.ylim(top=2) #y邊界值
plt.show()

# %% [markdown]
# ## Histograms (這部分先暫時略過)

# %%
res = np.random.randn(1000)*0.2 + 0.4

# %% [markdown]
# Quick Histogram

# %%
plt.figure(figsize=(8,3))
plt.hist(res)
plt.show()

# %% [markdown]
# Change number of bins

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=30)
plt.show()

# %% [markdown]
# Convert to density plot

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=30, density=True)
plt.show()

# %% [markdown]
# Differnt style of bins (useful for plotting multiple histograms)

# %%
res2 = np.random.randn(1000)*0.2 + 0.4

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=30, density=True, histtype='step')
plt.hist(res2, bins=30, density=True, histtype='step')
plt.xlabel('$\hat{E}-E$', fontsize=20)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # A More Advanced API
#
# For more complicated plots, such as
#
# * Multiple subplots on 1 figure
# * Conveniently adding text to plots
# * Creating animations
#
# one needs to use a slightly more advanced API

# %% [markdown]
# ## Single Axes in one Figure

# %%
#用ax的方式來畫圖，不過本質上跟之前的方式是相通的
fig, ax = plt.subplots(1, 1, figsize=(12,4)) #兩個一是指畫一行一列的圖，也就是一張圖
ax.plot(x, y, 'o--', color='r', lw=0.4, ms=3)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$\frac{d}{dx} f(x)$', fontsize=15)
plt.show()

# %% [markdown]
# ## Multiple axes in 1 figure

# %%
# axe方法的真正威力
fig, axes = plt.subplots(3, 2, figsize=(8,8))

ax = axes[0][0]
ax.plot(x, y, 'o--', color='r', lw=0.4, ms=3)
ax.text(0.1, 0.1, 'text here', transform=ax.transAxes)
#transform=ax.transAxes 表示這個位置是以子圖的「相對座標」來定位的，0是最左邊/下方，1是最右邊/上方


ax = axes[1][1] #指定是哪個圖
#以下是跳過的柱狀圖的部分，res、res2是數據矩陣名稱，要先在柱狀圖那邊跑過，不然會出現錯誤
ax.hist(res, bins=30, density=True, histtype='step', label='C1')
ax.hist(res2, bins=30, density=True, histtype='step', label='C2')
#下面的圖表標題，並顯示標題
ax.set_xlabel('$\hat{E}-E$')
ax.legend()


fig.tight_layout()
fig.suptitle('Title of All Plots', y=1.03, fontsize=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-28-3457312699.py in <cell line: 0>()
#      10 ax = axes[1][1] #指定是哪個圖
#      11 #以下是跳過的柱狀圖的部分
# ---> 12 ax.hist(res, bins=30, density=True, histtype='step', label='C1')
#      13 ax.hist(res2, bins=30, density=True, histtype='step', label='C1')
#      14 #下面的圖表標題，並顯示標題
#
# NameError: name 'res' is not defined

# %% [markdown]
# Can make x-ticks smaller

# %%
plt.style.use(['science', 'notebook', 'grid'])
fig, ax = plt.subplots(1, 1, figsize=(8,3))
ax.plot(x, y, 'o--', color='r', lw=1, ms=5)
ax.text(0.1, 0.1, 'text here', transform=ax.transAxes)
ax.set_xlabel('Time [s]')
ax.set_ylabel(r'$\frac{d}{dx} f(x)$', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.grid('minor')
plt.show()

#結論:
#x.tick_params(...)	調整刻度的樣式、控制文字大小、刻度方向等
#ax.grid('minor')	顯示小刻度網格線、視覺輔助用，非預設開啟

# %% [markdown]
# # Example
#
# Creating the following plot

# %%
res_a1 = 0.2*np.random.randn(1000)+0.4
res_b1 = 0.25*np.random.randn(1000)+0.4
res_a2 = 0.21*np.random.randn(1000)+0.3
res_b2 = 0.22*np.random.randn(1000)+0.3

# %% [markdown]
# Good habit to come up with complicated strings beforehand

# %%
textstr1 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a1)),
    r'$\sigma_b=%.4f$' % (np.std(res_b1))))

textstr2 = '\n'.join((
    r'$\sigma_a=%.4f$' % (np.std(res_a2)),
    r'$\sigma_b=%.4f$' % (np.std(res_b2))))

# %% [markdown]
# Make plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3.5))
ax = axes[0]
ax.hist(res_a1, bins=30, density=True, histtype='step', label='Method a', color='blue')
ax.hist(res_b1, bins=30, density=True, histtype='step', label='Method b', color='red')
ax.text(0.05, 0.81, textstr1, transform=ax.transAxes,
       bbox=dict(facecolor='white', edgecolor='black'), size=12)

ax.legend(fontsize=10, fancybox=False, edgecolor='black')
ax.set_ylabel('Frequency')
ax.set_title('Trial 1')
ax = axes[1]
ax.hist(res_a2, bins=30, density=True, histtype='step', label='Method 1', color='blue')
ax.hist(res_b2, bins=30, density=True, histtype='step', label='Method 2', color='red')
ax.text(0.05, 0.81, textstr2, transform=ax.transAxes,
       bbox=dict(facecolor='white', edgecolor='black'), size=12)
ax.set_title('Trial 2')
fig.text(0.5, -0.04, '$\Delta E$ [Joules]', ha='center', size=20)
plt.savefig('trial.png', dpi=200)
plt.show()

# %% [markdown]
# # 2D Plots

# %% [markdown]
# Generate some data

# %%
plt.style.use(['default'])

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y

# %% [markdown]
# ## Filled-in contour plots

# %%
plt.contourf(x,y,z)

# %% [markdown]
# Can make them more dense ny changing `levels` and also can change colormap
#
# * See https://matplotlib.org/stable/tutorials/colors/colormaps.html#sphx-glr-tutorials-colors-colormaps-py
#
# Can use `vmin` and `vmax` to adjust the color range
#
# * See https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.contour.html for all settings

# %%
plt.contourf(x,y,z, levels=50, cmap='plasma') #多加一個level值，圖形可以顯示越細膩與連續
#如果在後面加vmin=數字、vmax=數字，就是在某個值之後的所有值全部塗成該值的顏色而不再漸層
plt.colorbar(label='Temperature [$^\circ C$]') #就是旁邊那條，不想要標籤就打()就好
plt.xlabel('Horizontal Position [m]')
plt.ylabel('Vertical Position [m]')
# Out:
# Text(0, 0.5, 'Vertical Position [m]')

# %% [markdown]
# ## Contour Plot

# %% [markdown]
# Sometimes, the following is preferred:

# %%
#等高線圖
cs = plt.contour(x,y,z, levels=20)
plt.clabel(cs, fontsize=8)
# Out:
# <a list of 28 text.Text objects>

# %% [markdown]
# ## 3D Surface Plot

# %% [markdown]
# 3D Surface Plot (Generally not preferred). However, they tend to work well in animations (we'll get to this later)

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(x,y,z, cmap='coolwarm',
                       linewidth=0, antialiased=False)
ax.view_init(elev=10, azim=50)

# %% [markdown]
# ## StreamPlots

# %% [markdown]
# For plotting vector fields

# %%
w = 3
_ = np.linspace(-3,3,100)
X, Y = np.meshgrid(_,_)
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

# %%
fig, axes = plt.subplots(2,2,figsize=(5,5))
ax = axes[0][0]
ax.streamplot(X, Y, U, V)
ax = axes[0][1]
ax.streamplot(X, Y, U, V, color=speed)
ax = axes[1][0]
lw = 5*speed / speed.max()
ax.streamplot(X, Y, U, V, linewidth=lw)
ax = axes[1][1]
seed_points = np.array([[0,1], [1,0]])
ax.streamplot(X, Y, U, V, color=U, linewidth=2,
                      cmap='autumn', start_points=seed_points)
ax.grid()

# %% [markdown]
# # Image Reading

# %%
im = plt.imread('images/flower.png')

# %% [markdown]
# Plot image

# %%
plt.imshow(im)

# %% [markdown]
# # Animations

# %% [markdown]
# Animations require relating the time of your problem to the frame of the animation, then specifying the frames per second
#
# * Below is a $\sin$ wave moving at 3m/s. Translate this into an animation

# %%
def f(x,t):
    return np.sin(x-3*t)

x = np.linspace(0, 10*np.pi, 1000)
t = np.arange(0, 24, 1/60)
X, T = np.meshgrid(x, t)
F = f(X, T)

# %%
plt.plot(x, F[1])

# %% [markdown]
# Create animation

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
fig, ax = plt.subplots(1,1, figsize=(8,4))
ln1, = plt.plot([], [])
time_text = ax.text(0.65, 0.95, '', fontsize=15,
                    bbox=dict(facecolor='white', edgecolor='black'),
                    transform=ax.transAxes)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ln1.set_data(x, F[i])
    time_text.set_text('t={:.2f}'.format(i/60))

ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)

# %% [markdown]
# The animation function can be used in other ways too. One can create 3D rotating gifs of surfaces.

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(x,y,z, cmap='coolwarm',
                       linewidth=0, antialiased=False)
ax.view_init(elev=10, azim=0)

def animate(i):
    ax.view_init(elev=10, azim=3*i)

ani = animation.FuncAnimation(fig, animate, frames=120, interval=50)
ani.save('images/ani2.gif',writer='pillow',fps=30,dpi=100)
